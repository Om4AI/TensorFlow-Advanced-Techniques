# %% [markdown]
# # *Multi-Output: Wine Quality Estimator & Type Predictor*

# %% [markdown]
# ### *Code by @Om Mule*

# %% [markdown]
# ## *Dataset Information:*
# The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. For more details, consult: [Web Link] or the reference [Cortez et al., 2009]. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# These datasets can be viewed as classification or regression tasks. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Outlier detection algorithms could be used to detect the few excellent or poor wines. Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.

# %%
import tensorflow as tf
from tensorflow import keras
import sklearn
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.metrics import confusion_matrix
import itertools

import matplotlib.pyplot as plt
import seaborn as sns
import os
import zipfile
# %matplotlib inline

# %% [markdown]
# ## *Preprocess Datasets*

# %% [markdown]
# ### *White Wine Dataset*

# %%
# White wine dataset 
white_df = pd.read_csv("winequality-white.csv", sep=';')
white_df["is_red"] = 0
white_df.drop_duplicates(keep='first', inplace=True)
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 6            6.2              0.32         0.16             7.0      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 6                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality  is_red
# 0      8.8        6       0
# 1      9.5        6       0
# 2     10.1        6       0
# 3      9.9        6       0
# 6      9.6        6       0

# %%
white_df.size
# Out:
# 51493

# %% [markdown]
# ### *Red Wine Dataset*

# %%
# Red Wine dataset
red_df = pd.read_csv("winequality-red.csv", sep=";")
red_df["is_red"] = 1
red_df.drop_duplicates(keep='first', inplace=True)
red_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality  is_red
# 0      9.4        5       1
# 1      9.8        5       1
# 2      9.8        5       1
# 3      9.8        6       1
# 5      9.4        5       1

# %%
red_df.size
# Out:
# 17667

# %%
# Concatenate Datasets

df = pd.concat([red_df, white_df], ignore_index=True)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality  is_red
# 0      9.4        5       1
# 1      9.8        5       1
# 2      9.8        5       1
# 3      9.8        6       1
# 4      9.4        5       1

# %%
df.size
# Out:
# 69160

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 5315            6.2              0.21         0.29             1.6      0.039
# 5316            6.6              0.32         0.36             8.0      0.047
# 5317            6.5              0.24         0.19             1.2      0.041
# 5318            5.5              0.29         0.30             1.1      0.022
# 5319            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 5315                 24.0                  92.0  0.99114  3.27       0.50
# 5316                 57.0                 168.0  0.99490  3.15       0.46
# 5317                 30.0                 111.0  0.99254  2.99       0.46
# 5318                 20.0                 110.0  0.98869  3.34       0.38
# 5319                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  is_red
# 5315     11.2        6       0
# 5316      9.6        5       0
# 5317      9.4        6       0
# 5318     12.8        7       0
# 5319     11.8        6       0

# %% [markdown]
# ### *Wine Quality Plot*

# %%
sns.set_style(style="darkgrid")
plt.figure(figsize=(10,6))
plt.hist(df["quality"], color="orange")
plt.show()

# %% [markdown]
# #### *From the above plot, the wines with 3,4,8 & 9 have low number of examples but other have a good number of samples; thus removing the 3,4,8 & 9 samples.*

# %%
df.value_counts(df['quality'])
# Out:
# quality
# 6    2323
# 5    1752
# 7     856
# 4     206
# 8     148
# 3      30
# 9       5
# dtype: int64

# %%
df = df[(df['quality']>4) & (df['quality']<8)]
df = df.reset_index(drop=True)
df.value_counts(df['quality'])
# Out:
# quality
# 6    2323
# 5    1752
# 7     856
# dtype: int64

# %%
df['fixed acidity'].size
# Out:
# 4931

# %% [markdown]
# ### *Plot after processing*

# %%
sns.set_style(style="darkgrid")
plt.figure(figsize=(10,6))
plt.hist(df["quality"], color="orange")
plt.show()

# %% [markdown]
# ## *Train Test Split of the data*

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality  is_red
# 0      9.4        5       1
# 1      9.8        5       1
# 2      9.8        5       1
# 3      9.8        6       1
# 4      9.4        5       1

# %%
df.size
# Out:
# 64103

# %%
x = df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']]
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 4926            6.2              0.21         0.29             1.6      0.039
# 4927            6.6              0.32         0.36             8.0      0.047
# 4928            6.5              0.24         0.19             1.2      0.041
# 4929            5.5              0.29         0.30             1.1      0.022
# 4930            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 4926                 24.0                  92.0  0.99114  3.27       0.50
# 4927                 57.0                 168.0  0.99490  3.15       0.46
# 4928                 30.0                 111.0  0.99254  2.99       0.46
# 4929                 20.0                 110.0  0.98869  3.34       0.38
# 4930                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 4926     11.2
# 4927      9.6
# 4928      9.4
# 4929     12.8
# 4930     11.8
#
# [4931 rows x 11 columns]

# %%
y = df[['quality', 'is_red']]
y.head()
# Out:
#    quality  is_red
# 0        5       1
# 1        5       1
# 2        5       1
# 3        6       1
# 4        5       1

# %%
y.size
# Out:
# 9862

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, random_state=1)
print(train_x.size)
print(test_x.size)
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.2, random_state=1)
print(val_x.size)
# Out:
# 43384
# 10857
# 8679

# %%
train_x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 225             7.5              0.65         0.18            7.00      0.088
# 3557            6.3              0.27         0.29           12.20      0.044
# 3825            8.8              0.27         0.25            5.00      0.024
# 1740            6.4              0.45         0.07            1.10      0.030
# 1221            7.2              0.53         0.13            2.00      0.058
# ...             ...               ...          ...             ...        ...
# 1916            7.0              0.21         0.37            7.20      0.042
# 606             9.2              0.53         0.24            2.60      0.078
# 1255            6.0              0.58         0.20            2.40      0.075
# 959             6.8              0.66         0.07            1.60      0.070
# 2887            6.0              0.28         0.22           12.15      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 225                  27.0                  94.0  0.99915  3.38       0.77
# 3557                 59.0                 196.0  0.99782  3.14       0.40
# 3825                 52.0                  99.0  0.99250  2.87       0.49
# 1740                 10.0                 131.0  0.99050  2.97       0.28
# 1221                 18.0                  22.0  0.99573  3.21       0.68
# ...                   ...                   ...      ...   ...        ...
# 1916                 36.0                 167.0  0.99580  3.26       0.56
# 606                  28.0                 139.0  0.99788  3.21       0.57
# 1255                 15.0                  50.0  0.99467  3.58       0.67
# 959                  16.0                  61.0  0.99572  3.29       0.60
# 2887                 42.0                 163.0  0.99570  3.20       0.46
#
#       alcohol
# 225       9.4
# 3557      8.8
# 3825     11.4
# 1740     10.8
# 1221      9.9
# ...       ...
# 1916      9.8
# 606       9.5
# 1255     12.5
# 959       9.3
# 2887     10.1
#
# [3155 rows x 11 columns]

# %% [markdown]
# ## *train_x, train_y, test_x, test_y, val_x, val_y: Are all the sets created*

# %% [markdown]
# ## *Normalization*

# %%
train_stats = train_x.describe().transpose()
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         3155.0    7.221616   1.325297  3.80000   6.40000
# volatile acidity      3155.0    0.338929   0.162476  0.08000   0.23000
# citric acid           3155.0    0.321569   0.147970  0.00000   0.25000
# residual sugar        3155.0    5.155911   4.639632  0.60000   1.80000
# chlorides             3155.0    0.056976   0.036802  0.01200   0.03800
# free sulfur dioxide   3155.0   30.388590  17.236784  1.00000  17.00000
# total sulfur dioxide  3155.0  115.062282  56.706617  6.00000  75.00000
# density               3155.0    0.994633   0.003005  0.98711   0.99232
# pH                    3155.0    3.223201   0.161272  2.72000   3.11000
# sulphates             3155.0    0.534051   0.149149  0.22000   0.43000
# alcohol               3155.0   10.504466   1.154654  8.50000   9.50000
#
#                             50%       75%        max
# fixed acidity           7.00000    7.7000   15.60000
# volatile acidity        0.29000    0.4000    1.24000
# citric acid             0.31000    0.4000    1.66000
# residual sugar          2.80000    7.6500   65.80000
# chlorides               0.04700    0.0660    0.61100
# free sulfur dioxide    28.00000   41.0000  131.00000
# total sulfur dioxide  117.00000  156.0000  344.00000
# density                 0.99481    0.9968    1.03898
# pH                      3.21000    3.3300    4.01000
# sulphates               0.51000    0.6000    1.95000
# alcohol                10.30000   11.3000   14.00000

# %%
# train_x.mean()

# %%
# train_x.std()

# %%
# Normalize

norm_train_x = (train_x - train_x.mean())/train_x.std()
norm_train_x.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 225        0.210054          1.914565    -0.956741        0.397464   0.842996
# 3557      -0.695404         -0.424239    -0.213347        1.518243  -0.352585
# 3825       1.190966         -0.424239    -0.483672       -0.033604  -0.896032
# 1740      -0.619949          0.683616    -1.700136       -0.874188  -0.732998
# 1221      -0.016311          1.175995    -1.294648       -0.680207   0.027827
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 225             -0.196591             -0.371425  1.503235  0.972264
# 3557             1.659904              1.427306  1.060647 -0.515907
# 3825             1.253796             -0.283252 -0.709707 -2.190100
# 1740            -1.182853              0.281056 -1.375253 -1.570029
# 1221            -0.718730             -1.641119  0.365151 -0.081857
#
#       sulphates   alcohol
# 225    1.581966 -0.956534
# 3557  -0.898768 -1.476170
# 3825  -0.295346  0.775586
# 1740  -1.703331  0.255950
# 1221   0.978544 -0.523504

# %%
norm_val_x = (val_x - train_x.mean())/train_x.std()
norm_val_x.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4149       0.134599         -0.731976    -0.348510       -0.766421   0.000655
# 4340      -0.846313         -0.547333    -0.280928        1.044067  -0.053690
# 2045      -0.619949         -0.362691     0.597629        0.354358  -0.325413
# 1966      -0.846313         -0.362691     0.192141        1.647564  -0.243896
# 3452      -0.242675          0.375878    -0.145766        1.173388  -0.651481
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 4149             0.847688             -0.300887 -0.546648  0.414200
# 4340             1.485858              0.281056 -0.210547 -0.019850
# 2045             1.775935              1.779999  0.188781 -0.825943
# 1966             1.891966              2.009249  0.954159 -0.887950
# 3452            -0.370637             -0.494868 -0.659791 -0.453900
#
#       sulphates   alcohol
# 4149  -0.630581 -0.523504
# 4340  -1.234002  0.342556
# 2045  -0.496487 -0.956534
# 1966  -0.898768 -1.389564
# 3452  -0.563534  1.988071

# %%
norm_test_x = (test_x - train_x.mean())/train_x.std()
norm_test_x.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2372      -0.242675         -0.670428    -0.551254        1.949312  -0.108035
# 1900      -0.469039         -0.793523    -0.078184        1.345815  -0.488447
# 275        1.266420          0.560521     0.867954       -0.701761  -0.135207
# 3276      -0.619949          2.099207    -0.416091       -0.378459   0.326722
# 2360      -0.469039         -0.670428    -0.416091       -0.831081  -0.325413
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 2372            -0.660714             -0.371425  1.187100 -0.329886
# 1900             0.905703              0.880633  1.103907  1.158285
# 275             -1.414915             -1.746926  0.055672  0.786243
# 3276            -0.312622              0.545575 -0.386917 -0.267879
# 2360            -0.834761              0.228152 -0.410211  0.848250
#
#       sulphates   alcohol
# 2372  -0.228299 -0.783322
# 1900  -0.630581 -0.610110
# 275    1.112638  1.728253
# 3276  -0.898768 -1.043140
# 2360   0.442169 -0.436898

# %% [markdown]
# ## *Model Development*

# %%
# Initialize base model
def base_model(inputs):
    x = Dense(128, activation = 'relu', name = "First_Dense")(inputs)
    x = Dense(128, activation = 'relu', name='Second_Dense')(x)
    return x

# %%
def final_model(inputs):
    x = base_model(inputs)
    # Output layers
    
    wine_quality = Dense(1, name='Wine_Quality')(x)
    wine_type = Dense(1, activation='sigmoid', name="Wine_Type")(x)
    model = Model(inputs = inputs, outputs =[wine_quality, wine_type])
    return model

# %% [markdown]
# ## *Compile the model*

# %%
inputs = Input(shape=(11,))
model = final_model(inputs)

# %%
keras.utils.plot_model(model, show_shapes= True, show_layer_names=True)

# %%
model.compile(optimizer = keras.optimizers.RMSprop(learning_rate= 0.0001), 
              loss = {'Wine_Type':'binary_crossentropy',
                      'Wine_Quality': 'mean_squared_error'},
              metrics = {'Wine_Type': 'accuracy',
                         'Wine_Quality': tf.keras.metrics.RootMeanSquaredError()},
             )

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 11)]         0
# __________________________________________________________________________________________________
# First_Dense (Dense)             (None, 128)          1536        input_3[0][0]
# __________________________________________________________________________________________________
# Second_Dense (Dense)            (None, 128)          16512       First_Dense[0][0]
# __________________________________________________________________________________________________
# Wine_Quality (Dense)            (None, 1)            129         Second_Dense[0][0]
# __________________________________________________________________________________________________
# Wine_Type (Dense)               (None, 1)            129         Second_Dense[0][0]
# ==================================================================================================
# Total params: 18,306
# Trainable params: 18,306
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## *Train the model*

# %%
is_red = train_y['is_red']
is_red = np.array(is_red)
quality = train_y['quality']
quality = np.array(quality)
train_y = (quality, is_red)

# %%
train_y
# Out:
# (array([5, 6, 5, ..., 6, 5, 5], dtype=int64),
#  array([1, 0, 0, ..., 1, 1, 0], dtype=int64))

# %%
is_red = val_y['is_red']
is_red = np.array(is_red)
quality = val_y['quality']
quality = np.array(quality)
val_y = (quality, is_red)

# %%
is_red = test_y['is_red']
is_red = np.array(is_red)
quality = test_y['quality']
quality = np.array(quality)
test_y = (quality, is_red)

# %%
history = model.fit(norm_train_x, train_y, 
                    epochs=180, 
                    validation_data=(norm_val_x, val_y))
# Out:
# Epoch 1/180
# 99/99 [==============================] - 2s 16ms/step - loss: 23.2641 - Wine_Quality_loss: 22.5111 - Wine_Type_loss: 0.7531 - Wine_Quality_root_mean_squared_error: 4.7446 - Wine_Type_accuracy: 0.2802 - val_loss: 14.9148 - val_Wine_Quality_loss: 14.2052 - val_Wine_Type_loss: 0.7096 - val_Wine_Quality_root_mean_squared_error: 3.7690 - val_Wine_Type_accuracy: 0.4816
# Epoch 2/180
# 99/99 [==============================] - 0s 4ms/step - loss: 8.9329 - Wine_Quality_loss: 8.2718 - Wine_Type_loss: 0.6611 - Wine_Quality_root_mean_squared_error: 2.8761 - Wine_Type_accuracy: 0.6818 - val_loss: 4.5573 - val_Wine_Quality_loss: 3.9463 - val_Wine_Type_loss: 0.6109 - val_Wine_Quality_root_mean_squared_error: 1.9865 - val_Wine_Type_accuracy: 0.8441
# Epoch 3/180
# 99/99 [==============================] - 0s 4ms/step - loss: 3.2378 - Wine_Quality_loss: 2.6950 - Wine_Type_loss: 0.5427 - Wine_Quality_root_mean_squared_error: 1.6417 - Wine_Type_accuracy: 0.8304 - val_loss: 2.6698 - val_Wine_Quality_loss: 2.1857 - val_Wine_Type_loss: 0.4841 - val_Wine_Quality_root_mean_squared_error: 1.4784 - val_Wine_Type_accuracy: 0.8213
# Epoch 4/180
# 99/99 [==============================] - 0s 4ms/step - loss: 2.4378 - Wine_Quality_loss: 2.0194 - Wine_Type_loss: 0.4184 - Wine_Quality_root_mean_squared_error: 1.4211 - Wine_Type_accuracy: 0.8586 - val_loss: 2.2696 - val_Wine_Quality_loss: 1.8942 - val_Wine_Type_loss: 0.3754 - val_Wine_Quality_root_mean_squared_error: 1.3763 - val_Wine_Type_accuracy: 0.8821
# Epoch 5/180
# 99/99 [==============================] - 0s 4ms/step - loss: 2.1098 - Wine_Quality_loss: 1.7857 - Wine_Type_loss: 0.3240 - Wine_Quality_root_mean_squared_error: 1.3363 - Wine_Type_accuracy: 0.9192 - val_loss: 1.9948 - val_Wine_Quality_loss: 1.7047 - val_Wine_Type_loss: 0.2901 - val_Wine_Quality_root_mean_squared_error: 1.3056 - val_Wine_Type_accuracy: 0.9341
# Epoch 6/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.8642 - Wine_Quality_loss: 1.6169 - Wine_Type_loss: 0.2473 - Wine_Quality_root_mean_squared_error: 1.2716 - Wine_Type_accuracy: 0.9601 - val_loss: 1.7862 - val_Wine_Quality_loss: 1.5633 - val_Wine_Type_loss: 0.2229 - val_Wine_Quality_root_mean_squared_error: 1.2503 - val_Wine_Type_accuracy: 0.9683
# Epoch 7/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.6736 - Wine_Quality_loss: 1.4820 - Wine_Type_loss: 0.1916 - Wine_Quality_root_mean_squared_error: 1.2174 - Wine_Type_accuracy: 0.9721 - val_loss: 1.6113 - val_Wine_Quality_loss: 1.4377 - val_Wine_Type_loss: 0.1735 - val_Wine_Quality_root_mean_squared_error: 1.1991 - val_Wine_Type_accuracy: 0.9772
# Epoch 8/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.5230 - Wine_Quality_loss: 1.3725 - Wine_Type_loss: 0.1505 - Wine_Quality_root_mean_squared_error: 1.1716 - Wine_Type_accuracy: 0.9807 - val_loss: 1.4835 - val_Wine_Quality_loss: 1.3452 - val_Wine_Type_loss: 0.1384 - val_Wine_Quality_root_mean_squared_error: 1.1598 - val_Wine_Type_accuracy: 0.9848
# Epoch 9/180
# 99/99 [==============================] - 0s 3ms/step - loss: 1.4035 - Wine_Quality_loss: 1.2819 - Wine_Type_loss: 0.1216 - Wine_Quality_root_mean_squared_error: 1.1322 - Wine_Type_accuracy: 0.9861 - val_loss: 1.3590 - val_Wine_Quality_loss: 1.2453 - val_Wine_Type_loss: 0.1137 - val_Wine_Quality_root_mean_squared_error: 1.1159 - val_Wine_Type_accuracy: 0.9886
# Epoch 10/180
# 99/99 [==============================] - 0s 3ms/step - loss: 1.3020 - Wine_Quality_loss: 1.2006 - Wine_Type_loss: 0.1013 - Wine_Quality_root_mean_squared_error: 1.0957 - Wine_Type_accuracy: 0.9876 - val_loss: 1.2573 - val_Wine_Quality_loss: 1.1623 - val_Wine_Type_loss: 0.0950 - val_Wine_Quality_root_mean_squared_error: 1.0781 - val_Wine_Type_accuracy: 0.9899
# Epoch 11/180
# 99/99 [==============================] - 0s 3ms/step - loss: 1.2147 - Wine_Quality_loss: 1.1282 - Wine_Type_loss: 0.0865 - Wine_Quality_root_mean_squared_error: 1.0621 - Wine_Type_accuracy: 0.9883 - val_loss: 1.1749 - val_Wine_Quality_loss: 1.0928 - val_Wine_Type_loss: 0.0821 - val_Wine_Quality_root_mean_squared_error: 1.0454 - val_Wine_Type_accuracy: 0.9899
# Epoch 12/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.1325 - Wine_Quality_loss: 1.0569 - Wine_Type_loss: 0.0756 - Wine_Quality_root_mean_squared_error: 1.0280 - Wine_Type_accuracy: 0.9886 - val_loss: 1.0887 - val_Wine_Quality_loss: 1.0165 - val_Wine_Type_loss: 0.0722 - val_Wine_Quality_root_mean_squared_error: 1.0082 - val_Wine_Type_accuracy: 0.9899
# Epoch 13/180
# 99/99 [==============================] - 0s 4ms/step - loss: 1.0598 - Wine_Quality_loss: 0.9926 - Wine_Type_loss: 0.0672 - Wine_Quality_root_mean_squared_error: 0.9963 - Wine_Type_accuracy: 0.9889 - val_loss: 1.0155 - val_Wine_Quality_loss: 0.9506 - val_Wine_Type_loss: 0.0648 - val_Wine_Quality_root_mean_squared_error: 0.9750 - val_Wine_Type_accuracy: 0.9899
# Epoch 14/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.9854 - Wine_Quality_loss: 0.9244 - Wine_Type_loss: 0.0610 - Wine_Quality_root_mean_squared_error: 0.9615 - Wine_Type_accuracy: 0.9895 - val_loss: 0.9370 - val_Wine_Quality_loss: 0.8779 - val_Wine_Type_loss: 0.0590 - val_Wine_Quality_root_mean_squared_error: 0.9370 - val_Wine_Type_accuracy: 0.9899
# Epoch 15/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.9241 - Wine_Quality_loss: 0.8679 - Wine_Type_loss: 0.0562 - Wine_Quality_root_mean_squared_error: 0.9316 - Wine_Type_accuracy: 0.9905 - val_loss: 0.8747 - val_Wine_Quality_loss: 0.8198 - val_Wine_Type_loss: 0.0549 - val_Wine_Quality_root_mean_squared_error: 0.9054 - val_Wine_Type_accuracy: 0.9899
# Epoch 16/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.8731 - Wine_Quality_loss: 0.8206 - Wine_Type_loss: 0.0525 - Wine_Quality_root_mean_squared_error: 0.9059 - Wine_Type_accuracy: 0.9902 - val_loss: 0.8267 - val_Wine_Quality_loss: 0.7751 - val_Wine_Type_loss: 0.0516 - val_Wine_Quality_root_mean_squared_error: 0.8804 - val_Wine_Type_accuracy: 0.9899
# Epoch 17/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.8217 - Wine_Quality_loss: 0.7722 - Wine_Type_loss: 0.0495 - Wine_Quality_root_mean_squared_error: 0.8788 - Wine_Type_accuracy: 0.9905 - val_loss: 0.7829 - val_Wine_Quality_loss: 0.7342 - val_Wine_Type_loss: 0.0487 - val_Wine_Quality_root_mean_squared_error: 0.8568 - val_Wine_Type_accuracy: 0.9911
# Epoch 18/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.7787 - Wine_Quality_loss: 0.7318 - Wine_Type_loss: 0.0469 - Wine_Quality_root_mean_squared_error: 0.8554 - Wine_Type_accuracy: 0.9905 - val_loss: 0.7288 - val_Wine_Quality_loss: 0.6824 - val_Wine_Type_loss: 0.0464 - val_Wine_Quality_root_mean_squared_error: 0.8261 - val_Wine_Type_accuracy: 0.9911
# Epoch 19/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.7352 - Wine_Quality_loss: 0.6904 - Wine_Type_loss: 0.0448 - Wine_Quality_root_mean_squared_error: 0.8309 - Wine_Type_accuracy: 0.9905 - val_loss: 0.6951 - val_Wine_Quality_loss: 0.6506 - val_Wine_Type_loss: 0.0445 - val_Wine_Quality_root_mean_squared_error: 0.8066 - val_Wine_Type_accuracy: 0.9911
# Epoch 20/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6949 - Wine_Quality_loss: 0.6518 - Wine_Type_loss: 0.0431 - Wine_Quality_root_mean_squared_error: 0.8073 - Wine_Type_accuracy: 0.9905 - val_loss: 0.6557 - val_Wine_Quality_loss: 0.6127 - val_Wine_Type_loss: 0.0431 - val_Wine_Quality_root_mean_squared_error: 0.7827 - val_Wine_Type_accuracy: 0.9911
# Epoch 21/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6590 - Wine_Quality_loss: 0.6173 - Wine_Type_loss: 0.0416 - Wine_Quality_root_mean_squared_error: 0.7857 - Wine_Type_accuracy: 0.9908 - val_loss: 0.6193 - val_Wine_Quality_loss: 0.5777 - val_Wine_Type_loss: 0.0416 - val_Wine_Quality_root_mean_squared_error: 0.7601 - val_Wine_Type_accuracy: 0.9911
# Epoch 22/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6247 - Wine_Quality_loss: 0.5843 - Wine_Type_loss: 0.0404 - Wine_Quality_root_mean_squared_error: 0.7644 - Wine_Type_accuracy: 0.9908 - val_loss: 0.5896 - val_Wine_Quality_loss: 0.5490 - val_Wine_Type_loss: 0.0405 - val_Wine_Quality_root_mean_squared_error: 0.7410 - val_Wine_Type_accuracy: 0.9911
# Epoch 23/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6003 - Wine_Quality_loss: 0.5610 - Wine_Type_loss: 0.0393 - Wine_Quality_root_mean_squared_error: 0.7490 - Wine_Type_accuracy: 0.9911 - val_loss: 0.5614 - val_Wine_Quality_loss: 0.5216 - val_Wine_Type_loss: 0.0398 - val_Wine_Quality_root_mean_squared_error: 0.7222 - val_Wine_Type_accuracy: 0.9911
# Epoch 24/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.5732 - Wine_Quality_loss: 0.5347 - Wine_Type_loss: 0.0385 - Wine_Quality_root_mean_squared_error: 0.7312 - Wine_Type_accuracy: 0.9911 - val_loss: 0.5404 - val_Wine_Quality_loss: 0.5015 - val_Wine_Type_loss: 0.0389 - val_Wine_Quality_root_mean_squared_error: 0.7081 - val_Wine_Type_accuracy: 0.9911
# Epoch 25/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.5495 - Wine_Quality_loss: 0.5118 - Wine_Type_loss: 0.0377 - Wine_Quality_root_mean_squared_error: 0.7154 - Wine_Type_accuracy: 0.9914 - val_loss: 0.5202 - val_Wine_Quality_loss: 0.4819 - val_Wine_Type_loss: 0.0383 - val_Wine_Quality_root_mean_squared_error: 0.6942 - val_Wine_Type_accuracy: 0.9911
# Epoch 26/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.5263 - Wine_Quality_loss: 0.4893 - Wine_Type_loss: 0.0369 - Wine_Quality_root_mean_squared_error: 0.6995 - Wine_Type_accuracy: 0.9911 - val_loss: 0.4990 - val_Wine_Quality_loss: 0.4614 - val_Wine_Type_loss: 0.0376 - val_Wine_Quality_root_mean_squared_error: 0.6793 - val_Wine_Type_accuracy: 0.9924
# Epoch 27/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.5063 - Wine_Quality_loss: 0.4701 - Wine_Type_loss: 0.0362 - Wine_Quality_root_mean_squared_error: 0.6856 - Wine_Type_accuracy: 0.9911 - val_loss: 0.4834 - val_Wine_Quality_loss: 0.4464 - val_Wine_Type_loss: 0.0370 - val_Wine_Quality_root_mean_squared_error: 0.6681 - val_Wine_Type_accuracy: 0.9911
# Epoch 28/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4885 - Wine_Quality_loss: 0.4528 - Wine_Type_loss: 0.0357 - Wine_Quality_root_mean_squared_error: 0.6729 - Wine_Type_accuracy: 0.9921 - val_loss: 0.4776 - val_Wine_Quality_loss: 0.4410 - val_Wine_Type_loss: 0.0365 - val_Wine_Quality_root_mean_squared_error: 0.6641 - val_Wine_Type_accuracy: 0.9911
# Epoch 29/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4743 - Wine_Quality_loss: 0.4392 - Wine_Type_loss: 0.0351 - Wine_Quality_root_mean_squared_error: 0.6627 - Wine_Type_accuracy: 0.9921 - val_loss: 0.4593 - val_Wine_Quality_loss: 0.4233 - val_Wine_Type_loss: 0.0360 - val_Wine_Quality_root_mean_squared_error: 0.6506 - val_Wine_Type_accuracy: 0.9924
# Epoch 30/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4601 - Wine_Quality_loss: 0.4255 - Wine_Type_loss: 0.0346 - Wine_Quality_root_mean_squared_error: 0.6523 - Wine_Type_accuracy: 0.9927 - val_loss: 0.4411 - val_Wine_Quality_loss: 0.4055 - val_Wine_Type_loss: 0.0356 - val_Wine_Quality_root_mean_squared_error: 0.6368 - val_Wine_Type_accuracy: 0.9924
# Epoch 31/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4467 - Wine_Quality_loss: 0.4126 - Wine_Type_loss: 0.0342 - Wine_Quality_root_mean_squared_error: 0.6423 - Wine_Type_accuracy: 0.9927 - val_loss: 0.4300 - val_Wine_Quality_loss: 0.3950 - val_Wine_Type_loss: 0.0351 - val_Wine_Quality_root_mean_squared_error: 0.6285 - val_Wine_Type_accuracy: 0.9937
# Epoch 32/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4359 - Wine_Quality_loss: 0.4022 - Wine_Type_loss: 0.0337 - Wine_Quality_root_mean_squared_error: 0.6342 - Wine_Type_accuracy: 0.9933 - val_loss: 0.4214 - val_Wine_Quality_loss: 0.3866 - val_Wine_Type_loss: 0.0348 - val_Wine_Quality_root_mean_squared_error: 0.6218 - val_Wine_Type_accuracy: 0.9937
# Epoch 33/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.4253 - Wine_Quality_loss: 0.3921 - Wine_Type_loss: 0.0332 - Wine_Quality_root_mean_squared_error: 0.6262 - Wine_Type_accuracy: 0.9930 - val_loss: 0.4138 - val_Wine_Quality_loss: 0.3792 - val_Wine_Type_loss: 0.0346 - val_Wine_Quality_root_mean_squared_error: 0.6158 - val_Wine_Type_accuracy: 0.9937
# Epoch 34/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4166 - Wine_Quality_loss: 0.3837 - Wine_Type_loss: 0.0329 - Wine_Quality_root_mean_squared_error: 0.6194 - Wine_Type_accuracy: 0.9933 - val_loss: 0.4079 - val_Wine_Quality_loss: 0.3737 - val_Wine_Type_loss: 0.0342 - val_Wine_Quality_root_mean_squared_error: 0.6113 - val_Wine_Type_accuracy: 0.9937
# Epoch 35/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4078 - Wine_Quality_loss: 0.3753 - Wine_Type_loss: 0.0325 - Wine_Quality_root_mean_squared_error: 0.6126 - Wine_Type_accuracy: 0.9930 - val_loss: 0.3964 - val_Wine_Quality_loss: 0.3624 - val_Wine_Type_loss: 0.0340 - val_Wine_Quality_root_mean_squared_error: 0.6020 - val_Wine_Type_accuracy: 0.9937
# Epoch 36/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4015 - Wine_Quality_loss: 0.3693 - Wine_Type_loss: 0.0321 - Wine_Quality_root_mean_squared_error: 0.6077 - Wine_Type_accuracy: 0.9933 - val_loss: 0.3928 - val_Wine_Quality_loss: 0.3591 - val_Wine_Type_loss: 0.0337 - val_Wine_Quality_root_mean_squared_error: 0.5992 - val_Wine_Type_accuracy: 0.9937
# Epoch 37/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3943 - Wine_Quality_loss: 0.3624 - Wine_Type_loss: 0.0318 - Wine_Quality_root_mean_squared_error: 0.6020 - Wine_Type_accuracy: 0.9930 - val_loss: 0.3894 - val_Wine_Quality_loss: 0.3560 - val_Wine_Type_loss: 0.0334 - val_Wine_Quality_root_mean_squared_error: 0.5967 - val_Wine_Type_accuracy: 0.9937
# Epoch 38/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3877 - Wine_Quality_loss: 0.3562 - Wine_Type_loss: 0.0315 - Wine_Quality_root_mean_squared_error: 0.5968 - Wine_Type_accuracy: 0.9940 - val_loss: 0.3823 - val_Wine_Quality_loss: 0.3491 - val_Wine_Type_loss: 0.0332 - val_Wine_Quality_root_mean_squared_error: 0.5908 - val_Wine_Type_accuracy: 0.9937
# Epoch 39/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3822 - Wine_Quality_loss: 0.3510 - Wine_Type_loss: 0.0312 - Wine_Quality_root_mean_squared_error: 0.5925 - Wine_Type_accuracy: 0.9937 - val_loss: 0.3789 - val_Wine_Quality_loss: 0.3458 - val_Wine_Type_loss: 0.0331 - val_Wine_Quality_root_mean_squared_error: 0.5880 - val_Wine_Type_accuracy: 0.9937
# Epoch 40/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3794 - Wine_Quality_loss: 0.3485 - Wine_Type_loss: 0.0310 - Wine_Quality_root_mean_squared_error: 0.5903 - Wine_Type_accuracy: 0.9937 - val_loss: 0.3778 - val_Wine_Quality_loss: 0.3449 - val_Wine_Type_loss: 0.0329 - val_Wine_Quality_root_mean_squared_error: 0.5873 - val_Wine_Type_accuracy: 0.9937
# Epoch 41/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3744 - Wine_Quality_loss: 0.3437 - Wine_Type_loss: 0.0307 - Wine_Quality_root_mean_squared_error: 0.5862 - Wine_Type_accuracy: 0.9933 - val_loss: 0.3792 - val_Wine_Quality_loss: 0.3465 - val_Wine_Type_loss: 0.0328 - val_Wine_Quality_root_mean_squared_error: 0.5886 - val_Wine_Type_accuracy: 0.9937
# Epoch 42/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3703 - Wine_Quality_loss: 0.3399 - Wine_Type_loss: 0.0304 - Wine_Quality_root_mean_squared_error: 0.5830 - Wine_Type_accuracy: 0.9937 - val_loss: 0.3678 - val_Wine_Quality_loss: 0.3352 - val_Wine_Type_loss: 0.0326 - val_Wine_Quality_root_mean_squared_error: 0.5789 - val_Wine_Type_accuracy: 0.9937
# Epoch 43/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3675 - Wine_Quality_loss: 0.3373 - Wine_Type_loss: 0.0302 - Wine_Quality_root_mean_squared_error: 0.5808 - Wine_Type_accuracy: 0.9937 - val_loss: 0.3650 - val_Wine_Quality_loss: 0.3326 - val_Wine_Type_loss: 0.0323 - val_Wine_Quality_root_mean_squared_error: 0.5767 - val_Wine_Type_accuracy: 0.9937
# Epoch 44/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3644 - Wine_Quality_loss: 0.3344 - Wine_Type_loss: 0.0300 - Wine_Quality_root_mean_squared_error: 0.5783 - Wine_Type_accuracy: 0.9937 - val_loss: 0.3664 - val_Wine_Quality_loss: 0.3343 - val_Wine_Type_loss: 0.0321 - val_Wine_Quality_root_mean_squared_error: 0.5782 - val_Wine_Type_accuracy: 0.9937
# Epoch 45/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3600 - Wine_Quality_loss: 0.3303 - Wine_Type_loss: 0.0297 - Wine_Quality_root_mean_squared_error: 0.5747 - Wine_Type_accuracy: 0.9946 - val_loss: 0.3660 - val_Wine_Quality_loss: 0.3339 - val_Wine_Type_loss: 0.0321 - val_Wine_Quality_root_mean_squared_error: 0.5778 - val_Wine_Type_accuracy: 0.9937
# Epoch 46/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3575 - Wine_Quality_loss: 0.3281 - Wine_Type_loss: 0.0295 - Wine_Quality_root_mean_squared_error: 0.5728 - Wine_Type_accuracy: 0.9943 - val_loss: 0.3701 - val_Wine_Quality_loss: 0.3381 - val_Wine_Type_loss: 0.0320 - val_Wine_Quality_root_mean_squared_error: 0.5815 - val_Wine_Type_accuracy: 0.9937
# Epoch 47/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3550 - Wine_Quality_loss: 0.3257 - Wine_Type_loss: 0.0293 - Wine_Quality_root_mean_squared_error: 0.5707 - Wine_Type_accuracy: 0.9940 - val_loss: 0.3640 - val_Wine_Quality_loss: 0.3323 - val_Wine_Type_loss: 0.0316 - val_Wine_Quality_root_mean_squared_error: 0.5765 - val_Wine_Type_accuracy: 0.9937
# Epoch 48/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3527 - Wine_Quality_loss: 0.3237 - Wine_Type_loss: 0.0290 - Wine_Quality_root_mean_squared_error: 0.5690 - Wine_Type_accuracy: 0.9940 - val_loss: 0.3621 - val_Wine_Quality_loss: 0.3306 - val_Wine_Type_loss: 0.0314 - val_Wine_Quality_root_mean_squared_error: 0.5750 - val_Wine_Type_accuracy: 0.9937
# Epoch 49/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3493 - Wine_Quality_loss: 0.3204 - Wine_Type_loss: 0.0288 - Wine_Quality_root_mean_squared_error: 0.5661 - Wine_Type_accuracy: 0.9946 - val_loss: 0.3577 - val_Wine_Quality_loss: 0.3264 - val_Wine_Type_loss: 0.0313 - val_Wine_Quality_root_mean_squared_error: 0.5713 - val_Wine_Type_accuracy: 0.9937
# Epoch 50/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3471 - Wine_Quality_loss: 0.3184 - Wine_Type_loss: 0.0287 - Wine_Quality_root_mean_squared_error: 0.5643 - Wine_Type_accuracy: 0.9946 - val_loss: 0.3753 - val_Wine_Quality_loss: 0.3442 - val_Wine_Type_loss: 0.0312 - val_Wine_Quality_root_mean_squared_error: 0.5867 - val_Wine_Type_accuracy: 0.9937
# Epoch 51/180
# 99/99 [==============================] - 0s 5ms/step - loss: 0.3462 - Wine_Quality_loss: 0.3178 - Wine_Type_loss: 0.0284 - Wine_Quality_root_mean_squared_error: 0.5637 - Wine_Type_accuracy: 0.9946 - val_loss: 0.3582 - val_Wine_Quality_loss: 0.3272 - val_Wine_Type_loss: 0.0310 - val_Wine_Quality_root_mean_squared_error: 0.5720 - val_Wine_Type_accuracy: 0.9937
# Epoch 52/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3440 - Wine_Quality_loss: 0.3158 - Wine_Type_loss: 0.0282 - Wine_Quality_root_mean_squared_error: 0.5619 - Wine_Type_accuracy: 0.9946 - val_loss: 0.3530 - val_Wine_Quality_loss: 0.3222 - val_Wine_Type_loss: 0.0308 - val_Wine_Quality_root_mean_squared_error: 0.5676 - val_Wine_Type_accuracy: 0.9937
# Epoch 53/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3424 - Wine_Quality_loss: 0.3143 - Wine_Type_loss: 0.0280 - Wine_Quality_root_mean_squared_error: 0.5607 - Wine_Type_accuracy: 0.9946 - val_loss: 0.3561 - val_Wine_Quality_loss: 0.3253 - val_Wine_Type_loss: 0.0308 - val_Wine_Quality_root_mean_squared_error: 0.5704 - val_Wine_Type_accuracy: 0.9937
# Epoch 54/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3394 - Wine_Quality_loss: 0.3115 - Wine_Type_loss: 0.0279 - Wine_Quality_root_mean_squared_error: 0.5581 - Wine_Type_accuracy: 0.9946 - val_loss: 0.3521 - val_Wine_Quality_loss: 0.3214 - val_Wine_Type_loss: 0.0307 - val_Wine_Quality_root_mean_squared_error: 0.5669 - val_Wine_Type_accuracy: 0.9937
# Epoch 55/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3385 - Wine_Quality_loss: 0.3109 - Wine_Type_loss: 0.0277 - Wine_Quality_root_mean_squared_error: 0.5576 - Wine_Type_accuracy: 0.9946 - val_loss: 0.3549 - val_Wine_Quality_loss: 0.3243 - val_Wine_Type_loss: 0.0306 - val_Wine_Quality_root_mean_squared_error: 0.5694 - val_Wine_Type_accuracy: 0.9937
# Epoch 56/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3380 - Wine_Quality_loss: 0.3105 - Wine_Type_loss: 0.0275 - Wine_Quality_root_mean_squared_error: 0.5572 - Wine_Type_accuracy: 0.9949 - val_loss: 0.3474 - val_Wine_Quality_loss: 0.3168 - val_Wine_Type_loss: 0.0306 - val_Wine_Quality_root_mean_squared_error: 0.5628 - val_Wine_Type_accuracy: 0.9937
# Epoch 57/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3364 - Wine_Quality_loss: 0.3091 - Wine_Type_loss: 0.0273 - Wine_Quality_root_mean_squared_error: 0.5559 - Wine_Type_accuracy: 0.9949 - val_loss: 0.3508 - val_Wine_Quality_loss: 0.3204 - val_Wine_Type_loss: 0.0304 - val_Wine_Quality_root_mean_squared_error: 0.5661 - val_Wine_Type_accuracy: 0.9937
# Epoch 58/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3336 - Wine_Quality_loss: 0.3064 - Wine_Type_loss: 0.0272 - Wine_Quality_root_mean_squared_error: 0.5536 - Wine_Type_accuracy: 0.9946 - val_loss: 0.3503 - val_Wine_Quality_loss: 0.3200 - val_Wine_Type_loss: 0.0303 - val_Wine_Quality_root_mean_squared_error: 0.5657 - val_Wine_Type_accuracy: 0.9937
# Epoch 59/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3331 - Wine_Quality_loss: 0.3061 - Wine_Type_loss: 0.0269 - Wine_Quality_root_mean_squared_error: 0.5533 - Wine_Type_accuracy: 0.9949 - val_loss: 0.3483 - val_Wine_Quality_loss: 0.3180 - val_Wine_Type_loss: 0.0303 - val_Wine_Quality_root_mean_squared_error: 0.5639 - val_Wine_Type_accuracy: 0.9937
# Epoch 60/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3315 - Wine_Quality_loss: 0.3047 - Wine_Type_loss: 0.0268 - Wine_Quality_root_mean_squared_error: 0.5520 - Wine_Type_accuracy: 0.9949 - val_loss: 0.3456 - val_Wine_Quality_loss: 0.3154 - val_Wine_Type_loss: 0.0302 - val_Wine_Quality_root_mean_squared_error: 0.5616 - val_Wine_Type_accuracy: 0.9937
# Epoch 61/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3317 - Wine_Quality_loss: 0.3050 - Wine_Type_loss: 0.0267 - Wine_Quality_root_mean_squared_error: 0.5523 - Wine_Type_accuracy: 0.9949 - val_loss: 0.3445 - val_Wine_Quality_loss: 0.3145 - val_Wine_Type_loss: 0.0300 - val_Wine_Quality_root_mean_squared_error: 0.5608 - val_Wine_Type_accuracy: 0.9937
# Epoch 62/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3294 - Wine_Quality_loss: 0.3029 - Wine_Type_loss: 0.0264 - Wine_Quality_root_mean_squared_error: 0.5504 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3586 - val_Wine_Quality_loss: 0.3285 - val_Wine_Type_loss: 0.0301 - val_Wine_Quality_root_mean_squared_error: 0.5732 - val_Wine_Type_accuracy: 0.9949
# Epoch 63/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3283 - Wine_Quality_loss: 0.3019 - Wine_Type_loss: 0.0263 - Wine_Quality_root_mean_squared_error: 0.5495 - Wine_Type_accuracy: 0.9949 - val_loss: 0.3452 - val_Wine_Quality_loss: 0.3153 - val_Wine_Type_loss: 0.0299 - val_Wine_Quality_root_mean_squared_error: 0.5615 - val_Wine_Type_accuracy: 0.9949
# Epoch 64/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3264 - Wine_Quality_loss: 0.3003 - Wine_Type_loss: 0.0261 - Wine_Quality_root_mean_squared_error: 0.5480 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3444 - val_Wine_Quality_loss: 0.3146 - val_Wine_Type_loss: 0.0298 - val_Wine_Quality_root_mean_squared_error: 0.5609 - val_Wine_Type_accuracy: 0.9949
# Epoch 65/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3263 - Wine_Quality_loss: 0.3003 - Wine_Type_loss: 0.0260 - Wine_Quality_root_mean_squared_error: 0.5480 - Wine_Type_accuracy: 0.9949 - val_loss: 0.3460 - val_Wine_Quality_loss: 0.3163 - val_Wine_Type_loss: 0.0297 - val_Wine_Quality_root_mean_squared_error: 0.5624 - val_Wine_Type_accuracy: 0.9949
# Epoch 66/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3249 - Wine_Quality_loss: 0.2991 - Wine_Type_loss: 0.0259 - Wine_Quality_root_mean_squared_error: 0.5469 - Wine_Type_accuracy: 0.9949 - val_loss: 0.3448 - val_Wine_Quality_loss: 0.3151 - val_Wine_Type_loss: 0.0297 - val_Wine_Quality_root_mean_squared_error: 0.5614 - val_Wine_Type_accuracy: 0.9949
# Epoch 67/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3238 - Wine_Quality_loss: 0.2982 - Wine_Type_loss: 0.0256 - Wine_Quality_root_mean_squared_error: 0.5461 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3430 - val_Wine_Quality_loss: 0.3135 - val_Wine_Type_loss: 0.0295 - val_Wine_Quality_root_mean_squared_error: 0.5599 - val_Wine_Type_accuracy: 0.9949
# Epoch 68/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3229 - Wine_Quality_loss: 0.2975 - Wine_Type_loss: 0.0255 - Wine_Quality_root_mean_squared_error: 0.5454 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3527 - val_Wine_Quality_loss: 0.3233 - val_Wine_Type_loss: 0.0294 - val_Wine_Quality_root_mean_squared_error: 0.5686 - val_Wine_Type_accuracy: 0.9949
# Epoch 69/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3221 - Wine_Quality_loss: 0.2968 - Wine_Type_loss: 0.0254 - Wine_Quality_root_mean_squared_error: 0.5448 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3461 - val_Wine_Quality_loss: 0.3169 - val_Wine_Type_loss: 0.0292 - val_Wine_Quality_root_mean_squared_error: 0.5629 - val_Wine_Type_accuracy: 0.9949
# Epoch 70/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3215 - Wine_Quality_loss: 0.2963 - Wine_Type_loss: 0.0252 - Wine_Quality_root_mean_squared_error: 0.5444 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3492 - val_Wine_Quality_loss: 0.3199 - val_Wine_Type_loss: 0.0293 - val_Wine_Quality_root_mean_squared_error: 0.5656 - val_Wine_Type_accuracy: 0.9949
# Epoch 71/180
# 99/99 [==============================] - ETA: 0s - loss: 0.3201 - Wine_Quality_loss: 0.2949 - Wine_Type_loss: 0.0252 - Wine_Quality_root_mean_squared_error: 0.5430 - Wine_Type_accuracy: 0.99 - 0s 3ms/step - loss: 0.3202 - Wine_Quality_loss: 0.2951 - Wine_Type_loss: 0.0251 - Wine_Quality_root_mean_squared_error: 0.5432 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3456 - val_Wine_Quality_loss: 0.3163 - val_Wine_Type_loss: 0.0293 - val_Wine_Quality_root_mean_squared_error: 0.5624 - val_Wine_Type_accuracy: 0.9949
# Epoch 72/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3197 - Wine_Quality_loss: 0.2948 - Wine_Type_loss: 0.0249 - Wine_Quality_root_mean_squared_error: 0.5430 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3416 - val_Wine_Quality_loss: 0.3125 - val_Wine_Type_loss: 0.0291 - val_Wine_Quality_root_mean_squared_error: 0.5590 - val_Wine_Type_accuracy: 0.9949
# Epoch 73/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3170 - Wine_Quality_loss: 0.2922 - Wine_Type_loss: 0.0247 - Wine_Quality_root_mean_squared_error: 0.5406 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3424 - val_Wine_Quality_loss: 0.3134 - val_Wine_Type_loss: 0.0290 - val_Wine_Quality_root_mean_squared_error: 0.5598 - val_Wine_Type_accuracy: 0.9949
# Epoch 74/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3172 - Wine_Quality_loss: 0.2925 - Wine_Type_loss: 0.0246 - Wine_Quality_root_mean_squared_error: 0.5409 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3423 - val_Wine_Quality_loss: 0.3134 - val_Wine_Type_loss: 0.0290 - val_Wine_Quality_root_mean_squared_error: 0.5598 - val_Wine_Type_accuracy: 0.9949
# Epoch 75/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3171 - Wine_Quality_loss: 0.2927 - Wine_Type_loss: 0.0244 - Wine_Quality_root_mean_squared_error: 0.5410 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3421 - val_Wine_Quality_loss: 0.3133 - val_Wine_Type_loss: 0.0288 - val_Wine_Quality_root_mean_squared_error: 0.5597 - val_Wine_Type_accuracy: 0.9949
# Epoch 76/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3152 - Wine_Quality_loss: 0.2909 - Wine_Type_loss: 0.0243 - Wine_Quality_root_mean_squared_error: 0.5393 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3546 - val_Wine_Quality_loss: 0.3259 - val_Wine_Type_loss: 0.0287 - val_Wine_Quality_root_mean_squared_error: 0.5709 - val_Wine_Type_accuracy: 0.9949
# Epoch 77/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3149 - Wine_Quality_loss: 0.2907 - Wine_Type_loss: 0.0242 - Wine_Quality_root_mean_squared_error: 0.5392 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3400 - val_Wine_Quality_loss: 0.3113 - val_Wine_Type_loss: 0.0287 - val_Wine_Quality_root_mean_squared_error: 0.5580 - val_Wine_Type_accuracy: 0.9949
# Epoch 78/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3137 - Wine_Quality_loss: 0.2897 - Wine_Type_loss: 0.0240 - Wine_Quality_root_mean_squared_error: 0.5382 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3380 - val_Wine_Quality_loss: 0.3093 - val_Wine_Type_loss: 0.0287 - val_Wine_Quality_root_mean_squared_error: 0.5562 - val_Wine_Type_accuracy: 0.9949
# Epoch 79/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3133 - Wine_Quality_loss: 0.2894 - Wine_Type_loss: 0.0239 - Wine_Quality_root_mean_squared_error: 0.5380 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3436 - val_Wine_Quality_loss: 0.3150 - val_Wine_Type_loss: 0.0286 - val_Wine_Quality_root_mean_squared_error: 0.5612 - val_Wine_Type_accuracy: 0.9949
# Epoch 80/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3121 - Wine_Quality_loss: 0.2883 - Wine_Type_loss: 0.0238 - Wine_Quality_root_mean_squared_error: 0.5369 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3401 - val_Wine_Quality_loss: 0.3115 - val_Wine_Type_loss: 0.0286 - val_Wine_Quality_root_mean_squared_error: 0.5582 - val_Wine_Type_accuracy: 0.9949
# Epoch 81/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3113 - Wine_Quality_loss: 0.2877 - Wine_Type_loss: 0.0237 - Wine_Quality_root_mean_squared_error: 0.5363 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3460 - val_Wine_Quality_loss: 0.3175 - val_Wine_Type_loss: 0.0286 - val_Wine_Quality_root_mean_squared_error: 0.5635 - val_Wine_Type_accuracy: 0.9949
# Epoch 82/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3108 - Wine_Quality_loss: 0.2873 - Wine_Type_loss: 0.0235 - Wine_Quality_root_mean_squared_error: 0.5360 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3451 - val_Wine_Quality_loss: 0.3165 - val_Wine_Type_loss: 0.0286 - val_Wine_Quality_root_mean_squared_error: 0.5626 - val_Wine_Type_accuracy: 0.9949
# Epoch 83/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3109 - Wine_Quality_loss: 0.2875 - Wine_Type_loss: 0.0234 - Wine_Quality_root_mean_squared_error: 0.5361 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3416 - val_Wine_Quality_loss: 0.3131 - val_Wine_Type_loss: 0.0285 - val_Wine_Quality_root_mean_squared_error: 0.5595 - val_Wine_Type_accuracy: 0.9949
# Epoch 84/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3092 - Wine_Quality_loss: 0.2860 - Wine_Type_loss: 0.0233 - Wine_Quality_root_mean_squared_error: 0.5348 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3447 - val_Wine_Quality_loss: 0.3162 - val_Wine_Type_loss: 0.0284 - val_Wine_Quality_root_mean_squared_error: 0.5623 - val_Wine_Type_accuracy: 0.9949
# Epoch 85/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3092 - Wine_Quality_loss: 0.2860 - Wine_Type_loss: 0.0232 - Wine_Quality_root_mean_squared_error: 0.5348 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3397 - val_Wine_Quality_loss: 0.3114 - val_Wine_Type_loss: 0.0284 - val_Wine_Quality_root_mean_squared_error: 0.5580 - val_Wine_Type_accuracy: 0.9949
# Epoch 86/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3093 - Wine_Quality_loss: 0.2862 - Wine_Type_loss: 0.0231 - Wine_Quality_root_mean_squared_error: 0.5350 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3420 - val_Wine_Quality_loss: 0.3138 - val_Wine_Type_loss: 0.0282 - val_Wine_Quality_root_mean_squared_error: 0.5602 - val_Wine_Type_accuracy: 0.9949
# Epoch 87/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3072 - Wine_Quality_loss: 0.2843 - Wine_Type_loss: 0.0229 - Wine_Quality_root_mean_squared_error: 0.5332 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3381 - val_Wine_Quality_loss: 0.3100 - val_Wine_Type_loss: 0.0281 - val_Wine_Quality_root_mean_squared_error: 0.5568 - val_Wine_Type_accuracy: 0.9949
# Epoch 88/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3078 - Wine_Quality_loss: 0.2849 - Wine_Type_loss: 0.0228 - Wine_Quality_root_mean_squared_error: 0.5338 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3410 - val_Wine_Quality_loss: 0.3129 - val_Wine_Type_loss: 0.0281 - val_Wine_Quality_root_mean_squared_error: 0.5594 - val_Wine_Type_accuracy: 0.9949
# Epoch 89/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3065 - Wine_Quality_loss: 0.2838 - Wine_Type_loss: 0.0227 - Wine_Quality_root_mean_squared_error: 0.5327 - Wine_Type_accuracy: 0.9952 - val_loss: 0.3363 - val_Wine_Quality_loss: 0.3082 - val_Wine_Type_loss: 0.0281 - val_Wine_Quality_root_mean_squared_error: 0.5552 - val_Wine_Type_accuracy: 0.9949
# Epoch 90/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3049 - Wine_Quality_loss: 0.2824 - Wine_Type_loss: 0.0226 - Wine_Quality_root_mean_squared_error: 0.5314 - Wine_Type_accuracy: 0.9956 - val_loss: 0.3389 - val_Wine_Quality_loss: 0.3108 - val_Wine_Type_loss: 0.0280 - val_Wine_Quality_root_mean_squared_error: 0.5575 - val_Wine_Type_accuracy: 0.9949
# Epoch 91/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3047 - Wine_Quality_loss: 0.2822 - Wine_Type_loss: 0.0225 - Wine_Quality_root_mean_squared_error: 0.5312 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3365 - val_Wine_Quality_loss: 0.3086 - val_Wine_Type_loss: 0.0279 - val_Wine_Quality_root_mean_squared_error: 0.5555 - val_Wine_Type_accuracy: 0.9949
# Epoch 92/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3046 - Wine_Quality_loss: 0.2821 - Wine_Type_loss: 0.0224 - Wine_Quality_root_mean_squared_error: 0.5312 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3417 - val_Wine_Quality_loss: 0.3139 - val_Wine_Type_loss: 0.0279 - val_Wine_Quality_root_mean_squared_error: 0.5602 - val_Wine_Type_accuracy: 0.9949
# Epoch 93/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3030 - Wine_Quality_loss: 0.2807 - Wine_Type_loss: 0.0223 - Wine_Quality_root_mean_squared_error: 0.5298 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3387 - val_Wine_Quality_loss: 0.3110 - val_Wine_Type_loss: 0.0277 - val_Wine_Quality_root_mean_squared_error: 0.5576 - val_Wine_Type_accuracy: 0.9949
# Epoch 94/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3031 - Wine_Quality_loss: 0.2810 - Wine_Type_loss: 0.0221 - Wine_Quality_root_mean_squared_error: 0.5301 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3441 - val_Wine_Quality_loss: 0.3162 - val_Wine_Type_loss: 0.0278 - val_Wine_Quality_root_mean_squared_error: 0.5623 - val_Wine_Type_accuracy: 0.9949
# Epoch 95/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3029 - Wine_Quality_loss: 0.2809 - Wine_Type_loss: 0.0220 - Wine_Quality_root_mean_squared_error: 0.5300 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3379 - val_Wine_Quality_loss: 0.3102 - val_Wine_Type_loss: 0.0277 - val_Wine_Quality_root_mean_squared_error: 0.5570 - val_Wine_Type_accuracy: 0.9949
# Epoch 96/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3014 - Wine_Quality_loss: 0.2794 - Wine_Type_loss: 0.0220 - Wine_Quality_root_mean_squared_error: 0.5286 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3416 - val_Wine_Quality_loss: 0.3139 - val_Wine_Type_loss: 0.0276 - val_Wine_Quality_root_mean_squared_error: 0.5603 - val_Wine_Type_accuracy: 0.9949
# Epoch 97/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3016 - Wine_Quality_loss: 0.2798 - Wine_Type_loss: 0.0218 - Wine_Quality_root_mean_squared_error: 0.5289 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3377 - val_Wine_Quality_loss: 0.3102 - val_Wine_Type_loss: 0.0276 - val_Wine_Quality_root_mean_squared_error: 0.5569 - val_Wine_Type_accuracy: 0.9949
# Epoch 98/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3011 - Wine_Quality_loss: 0.2794 - Wine_Type_loss: 0.0217 - Wine_Quality_root_mean_squared_error: 0.5286 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3351 - val_Wine_Quality_loss: 0.3077 - val_Wine_Type_loss: 0.0275 - val_Wine_Quality_root_mean_squared_error: 0.5547 - val_Wine_Type_accuracy: 0.9949
# Epoch 99/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2990 - Wine_Quality_loss: 0.2775 - Wine_Type_loss: 0.0215 - Wine_Quality_root_mean_squared_error: 0.5268 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3419 - val_Wine_Quality_loss: 0.3144 - val_Wine_Type_loss: 0.0275 - val_Wine_Quality_root_mean_squared_error: 0.5607 - val_Wine_Type_accuracy: 0.9949
# Epoch 100/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3003 - Wine_Quality_loss: 0.2789 - Wine_Type_loss: 0.0215 - Wine_Quality_root_mean_squared_error: 0.5281 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3363 - val_Wine_Quality_loss: 0.3089 - val_Wine_Type_loss: 0.0274 - val_Wine_Quality_root_mean_squared_error: 0.5557 - val_Wine_Type_accuracy: 0.9949
# Epoch 101/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2990 - Wine_Quality_loss: 0.2776 - Wine_Type_loss: 0.0214 - Wine_Quality_root_mean_squared_error: 0.5269 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3384 - val_Wine_Quality_loss: 0.3111 - val_Wine_Type_loss: 0.0273 - val_Wine_Quality_root_mean_squared_error: 0.5577 - val_Wine_Type_accuracy: 0.9949
# Epoch 102/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2976 - Wine_Quality_loss: 0.2764 - Wine_Type_loss: 0.0212 - Wine_Quality_root_mean_squared_error: 0.5257 - Wine_Type_accuracy: 0.9959 - val_loss: 0.3369 - val_Wine_Quality_loss: 0.3098 - val_Wine_Type_loss: 0.0271 - val_Wine_Quality_root_mean_squared_error: 0.5566 - val_Wine_Type_accuracy: 0.9949
# Epoch 103/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2987 - Wine_Quality_loss: 0.2776 - Wine_Type_loss: 0.0212 - Wine_Quality_root_mean_squared_error: 0.5269 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3359 - val_Wine_Quality_loss: 0.3087 - val_Wine_Type_loss: 0.0272 - val_Wine_Quality_root_mean_squared_error: 0.5556 - val_Wine_Type_accuracy: 0.9949
# Epoch 104/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2970 - Wine_Quality_loss: 0.2759 - Wine_Type_loss: 0.0211 - Wine_Quality_root_mean_squared_error: 0.5253 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3402 - val_Wine_Quality_loss: 0.3130 - val_Wine_Type_loss: 0.0271 - val_Wine_Quality_root_mean_squared_error: 0.5595 - val_Wine_Type_accuracy: 0.9949
# Epoch 105/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2968 - Wine_Quality_loss: 0.2758 - Wine_Type_loss: 0.0210 - Wine_Quality_root_mean_squared_error: 0.5252 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3348 - val_Wine_Quality_loss: 0.3077 - val_Wine_Type_loss: 0.0270 - val_Wine_Quality_root_mean_squared_error: 0.5547 - val_Wine_Type_accuracy: 0.9949
# Epoch 106/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2957 - Wine_Quality_loss: 0.2748 - Wine_Type_loss: 0.0209 - Wine_Quality_root_mean_squared_error: 0.5243 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3359 - val_Wine_Quality_loss: 0.3089 - val_Wine_Type_loss: 0.0271 - val_Wine_Quality_root_mean_squared_error: 0.5558 - val_Wine_Type_accuracy: 0.9949
# Epoch 107/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2949 - Wine_Quality_loss: 0.2741 - Wine_Type_loss: 0.0208 - Wine_Quality_root_mean_squared_error: 0.5236 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3390 - val_Wine_Quality_loss: 0.3119 - val_Wine_Type_loss: 0.0270 - val_Wine_Quality_root_mean_squared_error: 0.5585 - val_Wine_Type_accuracy: 0.9949
# Epoch 108/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2954 - Wine_Quality_loss: 0.2747 - Wine_Type_loss: 0.0207 - Wine_Quality_root_mean_squared_error: 0.5242 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3442 - val_Wine_Quality_loss: 0.3174 - val_Wine_Type_loss: 0.0269 - val_Wine_Quality_root_mean_squared_error: 0.5633 - val_Wine_Type_accuracy: 0.9949
# Epoch 109/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2948 - Wine_Quality_loss: 0.2743 - Wine_Type_loss: 0.0206 - Wine_Quality_root_mean_squared_error: 0.5237 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3369 - val_Wine_Quality_loss: 0.3101 - val_Wine_Type_loss: 0.0268 - val_Wine_Quality_root_mean_squared_error: 0.5569 - val_Wine_Type_accuracy: 0.9949
# Epoch 110/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2935 - Wine_Quality_loss: 0.2730 - Wine_Type_loss: 0.0205 - Wine_Quality_root_mean_squared_error: 0.5225 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3419 - val_Wine_Quality_loss: 0.3151 - val_Wine_Type_loss: 0.0268 - val_Wine_Quality_root_mean_squared_error: 0.5614 - val_Wine_Type_accuracy: 0.9949
# Epoch 111/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2932 - Wine_Quality_loss: 0.2729 - Wine_Type_loss: 0.0203 - Wine_Quality_root_mean_squared_error: 0.5224 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3343 - val_Wine_Quality_loss: 0.3075 - val_Wine_Type_loss: 0.0268 - val_Wine_Quality_root_mean_squared_error: 0.5546 - val_Wine_Type_accuracy: 0.9949
# Epoch 112/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2929 - Wine_Quality_loss: 0.2726 - Wine_Type_loss: 0.0203 - Wine_Quality_root_mean_squared_error: 0.5221 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3348 - val_Wine_Quality_loss: 0.3080 - val_Wine_Type_loss: 0.0268 - val_Wine_Quality_root_mean_squared_error: 0.5550 - val_Wine_Type_accuracy: 0.9949
# Epoch 113/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2922 - Wine_Quality_loss: 0.2720 - Wine_Type_loss: 0.0202 - Wine_Quality_root_mean_squared_error: 0.5215 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3368 - val_Wine_Quality_loss: 0.3101 - val_Wine_Type_loss: 0.0267 - val_Wine_Quality_root_mean_squared_error: 0.5569 - val_Wine_Type_accuracy: 0.9949
# Epoch 114/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2918 - Wine_Quality_loss: 0.2717 - Wine_Type_loss: 0.0201 - Wine_Quality_root_mean_squared_error: 0.5212 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3360 - val_Wine_Quality_loss: 0.3093 - val_Wine_Type_loss: 0.0266 - val_Wine_Quality_root_mean_squared_error: 0.5562 - val_Wine_Type_accuracy: 0.9949
# Epoch 115/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2903 - Wine_Quality_loss: 0.2703 - Wine_Type_loss: 0.0200 - Wine_Quality_root_mean_squared_error: 0.5200 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3363 - val_Wine_Quality_loss: 0.3096 - val_Wine_Type_loss: 0.0267 - val_Wine_Quality_root_mean_squared_error: 0.5564 - val_Wine_Type_accuracy: 0.9949
# Epoch 116/180
# 99/99 [==============================] - ETA: 0s - loss: 0.2923 - Wine_Quality_loss: 0.2708 - Wine_Type_loss: 0.0216 - Wine_Quality_root_mean_squared_error: 0.5204 - Wine_Type_accuracy: 0.99 - 0s 3ms/step - loss: 0.2908 - Wine_Quality_loss: 0.2709 - Wine_Type_loss: 0.0199 - Wine_Quality_root_mean_squared_error: 0.5205 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3412 - val_Wine_Quality_loss: 0.3146 - val_Wine_Type_loss: 0.0266 - val_Wine_Quality_root_mean_squared_error: 0.5609 - val_Wine_Type_accuracy: 0.9949
# Epoch 117/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2901 - Wine_Quality_loss: 0.2703 - Wine_Type_loss: 0.0198 - Wine_Quality_root_mean_squared_error: 0.5199 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3379 - val_Wine_Quality_loss: 0.3113 - val_Wine_Type_loss: 0.0266 - val_Wine_Quality_root_mean_squared_error: 0.5580 - val_Wine_Type_accuracy: 0.9949
# Epoch 118/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2898 - Wine_Quality_loss: 0.2701 - Wine_Type_loss: 0.0197 - Wine_Quality_root_mean_squared_error: 0.5197 - Wine_Type_accuracy: 0.9962 - val_loss: 0.3333 - val_Wine_Quality_loss: 0.3067 - val_Wine_Type_loss: 0.0265 - val_Wine_Quality_root_mean_squared_error: 0.5538 - val_Wine_Type_accuracy: 0.9949
# Epoch 119/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2893 - Wine_Quality_loss: 0.2697 - Wine_Type_loss: 0.0196 - Wine_Quality_root_mean_squared_error: 0.5194 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3397 - val_Wine_Quality_loss: 0.3130 - val_Wine_Type_loss: 0.0266 - val_Wine_Quality_root_mean_squared_error: 0.5595 - val_Wine_Type_accuracy: 0.9949
# Epoch 120/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2901 - Wine_Quality_loss: 0.2705 - Wine_Type_loss: 0.0196 - Wine_Quality_root_mean_squared_error: 0.5201 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3354 - val_Wine_Quality_loss: 0.3089 - val_Wine_Type_loss: 0.0265 - val_Wine_Quality_root_mean_squared_error: 0.5558 - val_Wine_Type_accuracy: 0.9949
# Epoch 121/180
# 99/99 [==============================] - 0s 5ms/step - loss: 0.2880 - Wine_Quality_loss: 0.2686 - Wine_Type_loss: 0.0194 - Wine_Quality_root_mean_squared_error: 0.5183 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3371 - val_Wine_Quality_loss: 0.3105 - val_Wine_Type_loss: 0.0266 - val_Wine_Quality_root_mean_squared_error: 0.5572 - val_Wine_Type_accuracy: 0.9949
# Epoch 122/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2873 - Wine_Quality_loss: 0.2679 - Wine_Type_loss: 0.0194 - Wine_Quality_root_mean_squared_error: 0.5176 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3342 - val_Wine_Quality_loss: 0.3078 - val_Wine_Type_loss: 0.0265 - val_Wine_Quality_root_mean_squared_error: 0.5548 - val_Wine_Type_accuracy: 0.9949
# Epoch 123/180
# 99/99 [==============================] - 0s 5ms/step - loss: 0.2878 - Wine_Quality_loss: 0.2685 - Wine_Type_loss: 0.0193 - Wine_Quality_root_mean_squared_error: 0.5182 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3366 - val_Wine_Quality_loss: 0.3102 - val_Wine_Type_loss: 0.0263 - val_Wine_Quality_root_mean_squared_error: 0.5570 - val_Wine_Type_accuracy: 0.9949
# Epoch 124/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2858 - Wine_Quality_loss: 0.2666 - Wine_Type_loss: 0.0192 - Wine_Quality_root_mean_squared_error: 0.5164 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3319 - val_Wine_Quality_loss: 0.3055 - val_Wine_Type_loss: 0.0264 - val_Wine_Quality_root_mean_squared_error: 0.5527 - val_Wine_Type_accuracy: 0.9949
# Epoch 125/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2871 - Wine_Quality_loss: 0.2680 - Wine_Type_loss: 0.0191 - Wine_Quality_root_mean_squared_error: 0.5177 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3373 - val_Wine_Quality_loss: 0.3110 - val_Wine_Type_loss: 0.0263 - val_Wine_Quality_root_mean_squared_error: 0.5577 - val_Wine_Type_accuracy: 0.9949
# Epoch 126/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2851 - Wine_Quality_loss: 0.2660 - Wine_Type_loss: 0.0191 - Wine_Quality_root_mean_squared_error: 0.5158 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3320 - val_Wine_Quality_loss: 0.3057 - val_Wine_Type_loss: 0.0263 - val_Wine_Quality_root_mean_squared_error: 0.5529 - val_Wine_Type_accuracy: 0.9949
# Epoch 127/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2848 - Wine_Quality_loss: 0.2658 - Wine_Type_loss: 0.0190 - Wine_Quality_root_mean_squared_error: 0.5156 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3321 - val_Wine_Quality_loss: 0.3058 - val_Wine_Type_loss: 0.0263 - val_Wine_Quality_root_mean_squared_error: 0.5530 - val_Wine_Type_accuracy: 0.9949
# Epoch 128/180
# ...
# Epoch 139/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2796 - Wine_Quality_loss: 0.2616 - Wine_Type_loss: 0.0180 - Wine_Quality_root_mean_squared_error: 0.5115 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3373 - val_Wine_Quality_loss: 0.3115 - val_Wine_Type_loss: 0.0259 - val_Wine_Quality_root_mean_squared_error: 0.5581 - val_Wine_Type_accuracy: 0.9949
# Epoch 140/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2791 - Wine_Quality_loss: 0.2612 - Wine_Type_loss: 0.0179 - Wine_Quality_root_mean_squared_error: 0.5111 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3337 - val_Wine_Quality_loss: 0.3078 - val_Wine_Type_loss: 0.0258 - val_Wine_Quality_root_mean_squared_error: 0.5548 - val_Wine_Type_accuracy: 0.9949
# Epoch 141/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2786 - Wine_Quality_loss: 0.2608 - Wine_Type_loss: 0.0178 - Wine_Quality_root_mean_squared_error: 0.5107 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3339 - val_Wine_Quality_loss: 0.3080 - val_Wine_Type_loss: 0.0259 - val_Wine_Quality_root_mean_squared_error: 0.5549 - val_Wine_Type_accuracy: 0.9949
# Epoch 142/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2790 - Wine_Quality_loss: 0.2613 - Wine_Type_loss: 0.0178 - Wine_Quality_root_mean_squared_error: 0.5111 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3367 - val_Wine_Quality_loss: 0.3109 - val_Wine_Type_loss: 0.0259 - val_Wine_Quality_root_mean_squared_error: 0.5576 - val_Wine_Type_accuracy: 0.9949
# Epoch 143/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2765 - Wine_Quality_loss: 0.2588 - Wine_Type_loss: 0.0177 - Wine_Quality_root_mean_squared_error: 0.5087 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3507 - val_Wine_Quality_loss: 0.3249 - val_Wine_Type_loss: 0.0258 - val_Wine_Quality_root_mean_squared_error: 0.5700 - val_Wine_Type_accuracy: 0.9949
# Epoch 144/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2779 - Wine_Quality_loss: 0.2603 - Wine_Type_loss: 0.0176 - Wine_Quality_root_mean_squared_error: 0.5102 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3389 - val_Wine_Quality_loss: 0.3131 - val_Wine_Type_loss: 0.0258 - val_Wine_Quality_root_mean_squared_error: 0.5596 - val_Wine_Type_accuracy: 0.9949
# Epoch 145/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2780 - Wine_Quality_loss: 0.2604 - Wine_Type_loss: 0.0176 - Wine_Quality_root_mean_squared_error: 0.5103 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3329 - val_Wine_Quality_loss: 0.3071 - val_Wine_Type_loss: 0.0258 - val_Wine_Quality_root_mean_squared_error: 0.5542 - val_Wine_Type_accuracy: 0.9949
# Epoch 146/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2773 - Wine_Quality_loss: 0.2598 - Wine_Type_loss: 0.0175 - Wine_Quality_root_mean_squared_error: 0.5097 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3295 - val_Wine_Quality_loss: 0.3038 - val_Wine_Type_loss: 0.0257 - val_Wine_Quality_root_mean_squared_error: 0.5512 - val_Wine_Type_accuracy: 0.9949
# Epoch 147/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2764 - Wine_Quality_loss: 0.2590 - Wine_Type_loss: 0.0174 - Wine_Quality_root_mean_squared_error: 0.5089 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3343 - val_Wine_Quality_loss: 0.3087 - val_Wine_Type_loss: 0.0256 - val_Wine_Quality_root_mean_squared_error: 0.5556 - val_Wine_Type_accuracy: 0.9949
# Epoch 148/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2761 - Wine_Quality_loss: 0.2588 - Wine_Type_loss: 0.0173 - Wine_Quality_root_mean_squared_error: 0.5087 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3347 - val_Wine_Quality_loss: 0.3090 - val_Wine_Type_loss: 0.0257 - val_Wine_Quality_root_mean_squared_error: 0.5559 - val_Wine_Type_accuracy: 0.9949
# Epoch 149/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2761 - Wine_Quality_loss: 0.2588 - Wine_Type_loss: 0.0173 - Wine_Quality_root_mean_squared_error: 0.5087 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3336 - val_Wine_Quality_loss: 0.3080 - val_Wine_Type_loss: 0.0257 - val_Wine_Quality_root_mean_squared_error: 0.5549 - val_Wine_Type_accuracy: 0.9949
# Epoch 150/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2746 - Wine_Quality_loss: 0.2574 - Wine_Type_loss: 0.0172 - Wine_Quality_root_mean_squared_error: 0.5073 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3314 - val_Wine_Quality_loss: 0.3057 - val_Wine_Type_loss: 0.0257 - val_Wine_Quality_root_mean_squared_error: 0.5529 - val_Wine_Type_accuracy: 0.9949
# Epoch 151/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2749 - Wine_Quality_loss: 0.2578 - Wine_Type_loss: 0.0171 - Wine_Quality_root_mean_squared_error: 0.5078 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3373 - val_Wine_Quality_loss: 0.3117 - val_Wine_Type_loss: 0.0257 - val_Wine_Quality_root_mean_squared_error: 0.5583 - val_Wine_Type_accuracy: 0.9949
# Epoch 152/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2742 - Wine_Quality_loss: 0.2571 - Wine_Type_loss: 0.0170 - Wine_Quality_root_mean_squared_error: 0.5071 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3395 - val_Wine_Quality_loss: 0.3138 - val_Wine_Type_loss: 0.0257 - val_Wine_Quality_root_mean_squared_error: 0.5602 - val_Wine_Type_accuracy: 0.9949
# Epoch 153/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2739 - Wine_Quality_loss: 0.2569 - Wine_Type_loss: 0.0170 - Wine_Quality_root_mean_squared_error: 0.5068 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3410 - val_Wine_Quality_loss: 0.3154 - val_Wine_Type_loss: 0.0256 - val_Wine_Quality_root_mean_squared_error: 0.5616 - val_Wine_Type_accuracy: 0.9949
# Epoch 154/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2741 - Wine_Quality_loss: 0.2572 - Wine_Type_loss: 0.0169 - Wine_Quality_root_mean_squared_error: 0.5071 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3336 - val_Wine_Quality_loss: 0.3080 - val_Wine_Type_loss: 0.0256 - val_Wine_Quality_root_mean_squared_error: 0.5550 - val_Wine_Type_accuracy: 0.9949
# Epoch 155/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2724 - Wine_Quality_loss: 0.2556 - Wine_Type_loss: 0.0169 - Wine_Quality_root_mean_squared_error: 0.5056 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3382 - val_Wine_Quality_loss: 0.3126 - val_Wine_Type_loss: 0.0256 - val_Wine_Quality_root_mean_squared_error: 0.5591 - val_Wine_Type_accuracy: 0.9949
# Epoch 156/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2729 - Wine_Quality_loss: 0.2562 - Wine_Type_loss: 0.0167 - Wine_Quality_root_mean_squared_error: 0.5062 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3346 - val_Wine_Quality_loss: 0.3089 - val_Wine_Type_loss: 0.0257 - val_Wine_Quality_root_mean_squared_error: 0.5558 - val_Wine_Type_accuracy: 0.9949
# Epoch 157/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2728 - Wine_Quality_loss: 0.2560 - Wine_Type_loss: 0.0167 - Wine_Quality_root_mean_squared_error: 0.5060 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3356 - val_Wine_Quality_loss: 0.3100 - val_Wine_Type_loss: 0.0256 - val_Wine_Quality_root_mean_squared_error: 0.5568 - val_Wine_Type_accuracy: 0.9949
# Epoch 158/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2719 - Wine_Quality_loss: 0.2553 - Wine_Type_loss: 0.0166 - Wine_Quality_root_mean_squared_error: 0.5053 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3422 - val_Wine_Quality_loss: 0.3165 - val_Wine_Type_loss: 0.0257 - val_Wine_Quality_root_mean_squared_error: 0.5626 - val_Wine_Type_accuracy: 0.9949
# Epoch 159/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2714 - Wine_Quality_loss: 0.2547 - Wine_Type_loss: 0.0167 - Wine_Quality_root_mean_squared_error: 0.5047 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3342 - val_Wine_Quality_loss: 0.3087 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5556 - val_Wine_Type_accuracy: 0.9949
# Epoch 160/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2720 - Wine_Quality_loss: 0.2555 - Wine_Type_loss: 0.0165 - Wine_Quality_root_mean_squared_error: 0.5055 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3420 - val_Wine_Quality_loss: 0.3165 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5626 - val_Wine_Type_accuracy: 0.9949
# Epoch 161/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2706 - Wine_Quality_loss: 0.2542 - Wine_Type_loss: 0.0164 - Wine_Quality_root_mean_squared_error: 0.5042 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3344 - val_Wine_Quality_loss: 0.3089 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5558 - val_Wine_Type_accuracy: 0.9949
# Epoch 162/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2703 - Wine_Quality_loss: 0.2538 - Wine_Type_loss: 0.0165 - Wine_Quality_root_mean_squared_error: 0.5038 - Wine_Type_accuracy: 0.9965 - val_loss: 0.3325 - val_Wine_Quality_loss: 0.3069 - val_Wine_Type_loss: 0.0256 - val_Wine_Quality_root_mean_squared_error: 0.5540 - val_Wine_Type_accuracy: 0.9949
# Epoch 163/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2703 - Wine_Quality_loss: 0.2539 - Wine_Type_loss: 0.0164 - Wine_Quality_root_mean_squared_error: 0.5039 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3344 - val_Wine_Quality_loss: 0.3090 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5558 - val_Wine_Type_accuracy: 0.9949
# Epoch 164/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2694 - Wine_Quality_loss: 0.2531 - Wine_Type_loss: 0.0163 - Wine_Quality_root_mean_squared_error: 0.5031 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3366 - val_Wine_Quality_loss: 0.3111 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5578 - val_Wine_Type_accuracy: 0.9949
# Epoch 165/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2707 - Wine_Quality_loss: 0.2545 - Wine_Type_loss: 0.0162 - Wine_Quality_root_mean_squared_error: 0.5045 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3385 - val_Wine_Quality_loss: 0.3130 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5595 - val_Wine_Type_accuracy: 0.9949
# Epoch 166/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2687 - Wine_Quality_loss: 0.2525 - Wine_Type_loss: 0.0162 - Wine_Quality_root_mean_squared_error: 0.5025 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3385 - val_Wine_Quality_loss: 0.3130 - val_Wine_Type_loss: 0.0254 - val_Wine_Quality_root_mean_squared_error: 0.5595 - val_Wine_Type_accuracy: 0.9949
# Epoch 167/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2689 - Wine_Quality_loss: 0.2528 - Wine_Type_loss: 0.0161 - Wine_Quality_root_mean_squared_error: 0.5028 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3320 - val_Wine_Quality_loss: 0.3066 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5537 - val_Wine_Type_accuracy: 0.9949
# Epoch 168/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2680 - Wine_Quality_loss: 0.2520 - Wine_Type_loss: 0.0160 - Wine_Quality_root_mean_squared_error: 0.5020 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3349 - val_Wine_Quality_loss: 0.3095 - val_Wine_Type_loss: 0.0254 - val_Wine_Quality_root_mean_squared_error: 0.5563 - val_Wine_Type_accuracy: 0.9949
# Epoch 169/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2685 - Wine_Quality_loss: 0.2525 - Wine_Type_loss: 0.0160 - Wine_Quality_root_mean_squared_error: 0.5025 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3353 - val_Wine_Quality_loss: 0.3099 - val_Wine_Type_loss: 0.0254 - val_Wine_Quality_root_mean_squared_error: 0.5567 - val_Wine_Type_accuracy: 0.9949
# Epoch 170/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2687 - Wine_Quality_loss: 0.2528 - Wine_Type_loss: 0.0159 - Wine_Quality_root_mean_squared_error: 0.5028 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3320 - val_Wine_Quality_loss: 0.3066 - val_Wine_Type_loss: 0.0254 - val_Wine_Quality_root_mean_squared_error: 0.5537 - val_Wine_Type_accuracy: 0.9949
# Epoch 171/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2674 - Wine_Quality_loss: 0.2516 - Wine_Type_loss: 0.0158 - Wine_Quality_root_mean_squared_error: 0.5016 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3318 - val_Wine_Quality_loss: 0.3063 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5535 - val_Wine_Type_accuracy: 0.9949
# Epoch 172/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2678 - Wine_Quality_loss: 0.2520 - Wine_Type_loss: 0.0158 - Wine_Quality_root_mean_squared_error: 0.5020 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3337 - val_Wine_Quality_loss: 0.3082 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5551 - val_Wine_Type_accuracy: 0.9949
# Epoch 173/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2663 - Wine_Quality_loss: 0.2506 - Wine_Type_loss: 0.0157 - Wine_Quality_root_mean_squared_error: 0.5006 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3454 - val_Wine_Quality_loss: 0.3199 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5656 - val_Wine_Type_accuracy: 0.9949
# Epoch 174/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2665 - Wine_Quality_loss: 0.2509 - Wine_Type_loss: 0.0156 - Wine_Quality_root_mean_squared_error: 0.5009 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3401 - val_Wine_Quality_loss: 0.3145 - val_Wine_Type_loss: 0.0256 - val_Wine_Quality_root_mean_squared_error: 0.5608 - val_Wine_Type_accuracy: 0.9949
# Epoch 175/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2662 - Wine_Quality_loss: 0.2505 - Wine_Type_loss: 0.0156 - Wine_Quality_root_mean_squared_error: 0.5005 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3363 - val_Wine_Quality_loss: 0.3108 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5575 - val_Wine_Type_accuracy: 0.9949
# Epoch 176/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2664 - Wine_Quality_loss: 0.2508 - Wine_Type_loss: 0.0156 - Wine_Quality_root_mean_squared_error: 0.5008 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3341 - val_Wine_Quality_loss: 0.3087 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5556 - val_Wine_Type_accuracy: 0.9949
# Epoch 177/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2660 - Wine_Quality_loss: 0.2506 - Wine_Type_loss: 0.0155 - Wine_Quality_root_mean_squared_error: 0.5006 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3409 - val_Wine_Quality_loss: 0.3154 - val_Wine_Type_loss: 0.0254 - val_Wine_Quality_root_mean_squared_error: 0.5616 - val_Wine_Type_accuracy: 0.9949
# Epoch 178/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2646 - Wine_Quality_loss: 0.2491 - Wine_Type_loss: 0.0155 - Wine_Quality_root_mean_squared_error: 0.4991 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3371 - val_Wine_Quality_loss: 0.3116 - val_Wine_Type_loss: 0.0255 - val_Wine_Quality_root_mean_squared_error: 0.5582 - val_Wine_Type_accuracy: 0.9949
# Epoch 179/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2638 - Wine_Quality_loss: 0.2484 - Wine_Type_loss: 0.0154 - Wine_Quality_root_mean_squared_error: 0.4984 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3357 - val_Wine_Quality_loss: 0.3104 - val_Wine_Type_loss: 0.0253 - val_Wine_Quality_root_mean_squared_error: 0.5571 - val_Wine_Type_accuracy: 0.9949
# Epoch 180/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2648 - Wine_Quality_loss: 0.2495 - Wine_Type_loss: 0.0153 - Wine_Quality_root_mean_squared_error: 0.4995 - Wine_Type_accuracy: 0.9968 - val_loss: 0.3365 - val_Wine_Quality_loss: 0.3111 - val_Wine_Type_loss: 0.0254 - val_Wine_Quality_root_mean_squared_error: 0.5578 - val_Wine_Type_accuracy: 0.9949

# %% [markdown]
# ## *Analyze Model's performance*

# %%
loss, wine_quality_loss, wine_type_loss, wine_quality_rmse, wine_type_accuracy = model.evaluate(x=norm_val_x, y=val_y)

print()
print(f'loss: {loss}')
print(f'wine_quality_loss: {wine_quality_loss}')
print(f'wine_type_loss: {wine_type_loss}')
print(f'wine_quality_rmse: {wine_quality_rmse}')
print(f'wine_type_accuracy: {wine_type_accuracy}')
# Out:
# 25/25 [==============================] - 0s 880us/step - loss: 0.3365 - Wine_Quality_loss: 0.3111 - Wine_Type_loss: 0.0254 - Wine_Quality_root_mean_squared_error: 0.5578 - Wine_Type_accuracy: 0.9949
#
# loss: 0.336535781621933
# wine_quality_loss: 0.3111044764518738
# wine_type_loss: 0.02543131448328495
# wine_quality_rmse: 0.557767391204834
# wine_type_accuracy: 0.9949302673339844

# %%
predictions = model.predict(norm_test_x)
quality_preds = predictions[0]
type_preds = predictions[1]

# %% [markdown]
# ### *Plot utilities*

# %%
def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0,ylim)
    plt.plot(history.history[metric_name],color='blue',label=metric_name)
    plt.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)

def plot_confusion_matrix(y_true, y_pred, title='', labels=[0,1]):
    cm = confusion_matrix(y_true, y_pred)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
          plt.text(j, i, format(cm[i, j], fmt),
                  horizontalalignment="center",
                  color="black" if cm[i, j] > thresh else "white")
    plt.show()
    
def plot_diff(y_true, y_pred, title = '' ):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.plot([-100, 100], [-100, 100])
    return plt

# %% [markdown]
# ## *Metrics Plots*

# %%
plot_metrics('Wine_Quality_root_mean_squared_error', 'RMSE', ylim=2)

# %%
plot_metrics('Wine_Type_loss', 'Wine Type Loss', ylim=0.2)

# %% [markdown]
# ## *Confusion Matrix*

# %%
plot_confusion_matrix(test_y[1], np.round(type_preds), title='Wine Type', labels = [0, 1])
# Out:
# <ipython-input-125-3c2bb5135d98>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + labels)
# <ipython-input-125-3c2bb5135d98>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + labels)

# %%
plt.figure(figsize=(10,8))
scatter_plot = plot_diff(test_y[0], quality_preds, title='Type')
